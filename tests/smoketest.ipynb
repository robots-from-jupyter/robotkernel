# %%
*** Test Cases ***

One equals one
    Should be equal  "1"  "1"
# Out:
# <p><a href="javascript:(function(){var w=window.open();w.document.open();w.document.write(window.atob('...'));w.document.close();})();">Log</a> | <a href="javascript:(function(){var w=window.open();w.document.open();w.document.write(window.atob('...'));w.document.close();})();">Report</a></p>
