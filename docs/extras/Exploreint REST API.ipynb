# %%
*** Settings ***

Library  REST
Library  SeleniumLibrary
Library  SeleniumScreenshots

Test setup  Set default headers

*** Variables ***

${BASE_URL}  https://plonedemo.kitconcept.com

# %%
*** Keywords ***

Open singleton browser
    [Documentation]
    ...  Open a new browser window on the first call
    ...  and selects that window on the subsequent calls.
    Open browser  about:blank  alias=singleton  browser=headlessfirefox

Get authentication token
    Open singleton browser
    Go to  ${BASE_URL}/en/login
    Page should contain  Login as Editor
    Click link  Login as Editor
    Page should contain  You are now logged in
    ${cookie}=  Get cookie  __ac
    [Return]  ${cookie.value}

Set default headers
    ${token}=  Get authentication token
    ${headers}=  Create dictionary
    ...  Accept=application/json
    ...  ContentType=application/json
    ...  Cookie=__ac=${token}
    Set headers  ${headers}
# Out:
# Box(children=(Button(description='Open singleton browser', style=ButtonStyle()),), layout=Layout(display='flex…
# Output()
# Box(children=(Button(description='Get authentication token', style=ButtonStyle()),), layout=Layout(display='fl…
# Output()
# Box(children=(Button(description='Set default headers', style=ButtonStyle()),), layout=Layout(display='flex', …
# Output()

# %%
*** Tasks ***

Get folder listing
    Get  ${BASE_URL}/en
    Output  response body items 1
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <pre>{
#     <span style="color: #008000; font-weight: bold">&quot;@id&quot;</span>: <span style="color: #BA2121">&quot;https://plonedemo.kitconcept.com/en/frontpage&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;@type&quot;</span>: <span style="color: #BA2121">&quot;Document&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;description&quot;</span>: <span style="color: #BA2121">&quot;The ultimate Open Source Enterprise CMS&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;review_state&quot;</span>: <span style="color: #BA2121">&quot;published&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;title&quot;</span>: <span style="color: #BA2121">&quot;Welcome to Plone 5&quot;</span>
# }
# </pre>

# %%
*** Tasks ***

Get front page
    Go to  ${BASE_URL}/en/frontpage
    Capture and crop page screenshot
    ...  screenshot.png
    ...  id:content
    Get  ${BASE_URL}/en/frontpage
    Output  response body text
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <pre>{
#     <span style="color: #008000; font-weight: bold">&quot;content-type&quot;</span>: <span style="color: #BA2121">&quot;text/html&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;data&quot;</span>: <span style="color: #BA2121">&quot;&lt;p&gt;Edit this site and test Plone 5 now!&lt;/p&gt;&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;encoding&quot;</span>: <span style="color: #BA2121">&quot;utf-8&quot;</span>
# }
# </pre>

# %%
*** Tasks ***

Patch front page
    ${payload}=  Create dictionary
    ...  title=Hello World!
    ...  description=This is the front page.
    ...  text=<p>Here be much great content very.<p>
    Patch  ${BASE_URL}/en/frontpage  ${payload}
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <pre>{
#     <span style="color: #008000; font-weight: bold">&quot;seconds&quot;</span>: <span style="color: #666666">0.692646</span>,
#     <span style="color: #008000; font-weight: bold">&quot;status&quot;</span>: <span style="color: #666666">204</span>,
#     <span style="color: #008000; font-weight: bold">&quot;body&quot;</span>: <span style="color: #BA2121">&quot;&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;headers&quot;</span>: {
#         <span style="color: #008000; font-weight: bold">&quot;Server&quot;</span>: <span style="color: #BA2121">&quot;nginx&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Date&quot;</span>: <span style="color: #BA2121">&quot;Fri, 27 Dec 2019 00:08:27 GMT&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Connection&quot;</span>: <span style="color: #BA2121">&quot;keep-alive&quot;</span>
#     }
# }
# </pre>

# %%
*** Tasks ***

Get front page
    Go to  ${BASE_URL}/en/frontpage
    Capture and crop page screenshot
    ...  screenshot.png
    ...  id:content
    Get  ${BASE_URL}/en/frontpage
    Output  response body text
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <pre>{
#     <span style="color: #008000; font-weight: bold">&quot;content-type&quot;</span>: <span style="color: #BA2121">&quot;text/html&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;data&quot;</span>: <span style="color: #BA2121">&quot;&lt;p&gt;Here be much great content very.&lt;/p&gt;&lt;p/&gt;&quot;</span>,
#     <span style="color: #008000; font-weight: bold">&quot;encoding&quot;</span>: <span style="color: #BA2121">&quot;utf8&quot;</span>
# }
# </pre>
