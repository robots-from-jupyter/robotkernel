# %% [markdown]
# # Robots from Jupyter

# %% [markdown]
# Workshop on authoring Robot Framework test and task suites with JupyterLab

# %% [markdown]
# | Asko Soukka<br/>University of Jyväskylä | Nicholas Bollweg<br/>Project Jupyter |
# |:-----:|:----:|
# | <img src="asko.png" width="300" /> | <img src="nick.jpg" width="300" /> |

# %% [markdown]
# ## Agenda

# %% [markdown]
# * Setting up **Robot Framework on Jupyter**
# * Introduction to notebooks

# %% [markdown]
# * Exercise: **Python notebook**
# * Exercise: **Robot notebook**

# %% [markdown]
# ## Agenda

# %% [markdown]
# * Exercise: **Selenium autocompletions**
# * Exercise: **Prototyping keywords**
# * Exercise: **Protoping libraries**

# %% [markdown]
# * Importing notebooks
# * Sharing notebooks
# * Executing notebooks
# * Jupyter ecosystem

# %% [markdown]
# # Setting up Robot Framework on Jupyter

# %% [markdown]
# ## RobotLab installer
#
# https://github.com/robots-from-jupyter/robotlab/releases
#
#
# * Windows, MacOS, Linux
# * Desktop shortcut
#   <img src="robotlab.png" style="display: inline; width: 32px; margin-left: 0.5em;"/>
# * Offline installable
# * Substantial download size
#
# **Ingredients:** <small>Conda, JupyterLab, Robot[Mode|Kernel], Jupytext, Selenium[Library|Screenshots|Testability], OpenCV, RESTinstance, Firefox, GeckoDriver, starter notebooks...</small>

# %% [markdown]
# <center>
# Don't register RobotLab as the default Python 3.6 interpreter.
# <img src="installer-05.png" />
# </center>

# %% [markdown]
# ## Manual installation
#
# Install Miniconda, launch Anaconda Prompt, then:
#
# ```bash
# $ conda install -c conda-forge nodejs jupyterlab ipywidgets
#
# $ pip install robotkernel
#
# $ jupyter labextension install \
#   jupyterlab_robotmode --no-build
#
# $ jupyter labextension install \
#   @jupyter-widgets/jupyterlab-manager
# ```

# %% [markdown]
# ## Complementing manual installation
#
# Launch Anaconda Prompt, then:
#
# ```bash
# $ conda install -c conda-forge firefox geckodriver
#
# $ pip install robotframework-seleniumscreenshots \
#   RESTinstance jupytext jupyter-starters nbimporter
#
# $ jupyter labextension install \
#   jupyterlab-jupytext --no-build
#
# $ jupyter labextension install \
#   @deathbeds/jupyterlab-starters
# ```

# %% [markdown]
# ## Run JupyterLab manually
#
# From RobotLab with Windows Command Prompt:
# ```bash
# $ c:\robotlab\Scripts\activate.bat
# $ robotlab
# ```
#
# From RobotLab with MacOS / Linux terminal:
# ```bash
# $ source ~/robotlab/bin/activate
# $ robotlab
# ```
#
# From manually installed Anaconda Prompt:
# ```bash
# $ jupyter lab
# ```

# %% [markdown]
# # Introduction to JupyterLab
#
# ```
# 00 JupyterLab User Interface
# ```

# %% [markdown]
# <div style="margin-top:-60px"></div>
#
# ![](jupyterlab-01.png "")

# %% [markdown]
# <div style="margin-top:-60px"></div>
#
# ![](jupyterlab-02.png "")

# %% [markdown]
# <div style="margin-top:-60px"></div>
#
# ![](jupyterlab-03.png "")

# %% [markdown]
# # Introduction to notebooks
#
# ```
# 00 What is the Jupyter Notebook
# 00 Keyboard Shortcuts
# ```

# %% [markdown]
# <div style="margin-top:-120px"></div>
#
# ![](shortcuts.png "")

# %% [markdown]
# # Exercise: Python notebook
#
# ```
# 01 Running Code
# 02 Python XKCD
# ```

# %% [markdown]
# ## Exercise: Python
#
# The JSON API for XKCD is described at
#
# https://xkcd.com/json.html
#
# Create a new Python notebook and implement function, which accepts an integer and returns XKCD image of the given number.
# ```python
#     def get_xkcd_by_num(num):
#         return None
# ```
#
# Write narrative documentation for that function in Markdown and executable Python example lines.

# %% [markdown]
# ## Recap
#
# * JupyterLab interface and contextual help
# * Loading old and creating new notebooks
# * Navigating around notebooks
# * Copying, cutting, pasting and deleting cells
# * Editing and executing notebook cells
# * Autocompleting statements with `TAB`
# * Iterating cell with `CTRL + ENTER` until ready

# %% [markdown]
# ## Homework: magics
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html
#
# Magics are “magical” syntax for modifying the underlying Python environment  supported mainly by Jupyter Python kernels.
#
# For example
# ```bash
# !pip install requests
# ```
#
# would install requests Python package into Python environment.

# %% [markdown]
# # Exercise: Robot notebook
#
# ```
# 04 Robot XKCD
# ```

# %% [markdown]
# ## Robot Framework

# %%
*** Settings ***

Library  Collections

# %%
*** Variables ***

@{series}  1  2  3  4

# %%
*** Test Cases ***

Can append to list
    Append to list  ${series}  0
    ${length}=  Get length  ${series}
    Should be equal  "${length}"  "5"
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>

# %% [markdown]
# # Exercise: Robot
#
# Create a new Robot notebook and implement keyword
#
# ```robotframework
# *** Keywords ***
#
# Get XKCD by num
#     [Arguments]  ${num}
# ```
#
# which accepts an integer and `[Return]` image of the given number. Write narrative documentation for that keyword in Markdown and executable Robot example  `*** Tasks ***`.

# %% [markdown]
# ## Recap
#
# * Every Robot cell starts with a  `*** [Heading] ***`
# * Combining suite from multiple different cells
# * Autocompleting Robot Framework structural words
# * Autocompleting Robot Framework keywords
# * Using JupyterLab contextual help for keyword documentation
# * Viewing and downloading logs and reports
# * Restarting kernel to reset RobotKernel state

# %% [markdown]
# ## RobotKernel quirks
#
# * Some completions can be suggested only after at least one cell with `*** Test Cases ***` or `*** Tasks ***` has been executed.
#
# * Cells without any robot `*** [Heading] ***` or content outside headings may be silently ignored.
#
# * Failing library import is silently ignored (but logged).
#
# * Keyword documentation is not updated without restart.
#
# Thumb of rule for weird or erratic behavior: **Restart the kernel.**

# %% [markdown]
# ## Exercise: Selenium autocompletions
#
# ```
# 05 Interactive Selenium
# ```

# %% [markdown]
# ## Recap
#
# * Leaving a singleton test browser open while iterating
# * SeleniumLibrary locator prefixes with `TAB`-suggestions:<br/>
#   `id:`, `name:`, `link:`
# * SeleniumLibrary locator prefixes with `TAB`-completions:<br/>
#   `id:`, `name:`, `link:`, `tag:`, `xpath:`, `partial link:`
# * Interactive SeleniumLibrary picker with `css: + TAB`
# * Closing the test browser manually / with suite teardown

# %% [markdown]
# # Exercise: Prototyping keywords
#
# ```
# 07 Prototyping keywords
# ```

# %% [markdown]
# # Exercise: Prototyping libraries
#
# ```
# 09 Prototyping Libraries
# ```

# %% [markdown]
# # Importing Notebooks
#
# ```
# 06 Importing Notebooks
# ```

# %% [markdown]
# ## Exercise: Multiple notebooks
#
# Parameterize `06 Importing Notebooks` with
#
# ```robotframework
# *** Variables ***
#
# ${DEPARTURE_DATE}  ${EMPTY}
# ${DEPARTURE_TIME}  17.00
# ```
#
# Modify notebook task to use `${DEPARTURE_TIME}` and to prefer `${DEPARTURE_DATE}` when it is not empty. Customize or write new Python keywords when necessary.

# %% [markdown]
# ## Sharing and exporting notebooks
#
# Using JupyterLab
# ```
# File → Export Notebook As… →
# ```
#
# Using Jypyter nbconvert
#
# ```shell
# $ jupyter nbconvert --to html MyNotebook.ipynb
# ```
#
# How to customize `nbconvert` HTML-templates:
# https://nbconvert.readthedocs.io/en/latest/customizing.html

# %% [markdown]
# ## Executing notebooks
#
# Executing notebook with Jupyter
# ```shell
# jupyter nbconvert --to notebook --execute MyNotebook.ipynb
# ```
#
# Executing notebook with RobotKernel
# ```shell
# nbrobot MyNotebook.ipynb
# ```
#
# Executing exported script with Robot Framework
# ```shell
# jupyter nbconvert --to script MyNotebook.ipynb
# robot MyNotebook.robot
# ```

# %% [markdown]
# ## Jupyter ecosystem picks

# %% [markdown]
# ## Stable
#
# * [RISE](https://rise.readthedocs.io/) – interactive reveal.js slides for Notebook Classic
# * Vim-keybindings for [Notebook Classic](https://github.com/lambdalisue/jupyter-vim-binding) and [JupyterLab](https://github.com/jwkvam/jupyterlab-vim)
# * [Widgets](https://ipywidgets.readthedocs.io/) – interactive widgets for live notebooks
# * [Jupytext](https://jupytext.readthedocs.io/) – sync between `.ipynb` and `.robot`
#
# ## Emerging
#
# * [jupyterlab-starters](https://jupyterstarters.readthedocs.io/), [jupyterlab-commenting](https://github.com/jupyterlab/jupyterlab-commenting),<br>[jupyterlab-lsp](https://github.com/krassowski/jupyterlab-lsp), [jupyterlab-debugger](https://github.com/jupyterlab/debugger)

# %%
%%python module WidgetDemo

import ipywidgets as widgets
w = widgets.IntSlider()
display(w)

class WidgetDemo:
    def get_value(self):
        return w.value
# Out:
# IntSlider(value=0)

# %%
*** Settings ***

Library  WidgetDemo

*** Test Cases ***

Return widget value
    Get value
# Out:
# <p><a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="about:" onClick="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <span style="color: #666666">0</span>

# %% [markdown]
# ## Services
#
# * [NBViewer](https://nbviewer.jupyter.org/) – static previews for saved notebooks
# * [MyBinder](https://mybinder.org/) – reproducible live notebooks
# * [Google Colab](https://colab.research.google.com)
# * [Azure Notebooks](https://notebooks.azure.com/)
#
# ## Other
#
# * [JupyterHub](https://jupyterhub.readthedocs.io/) – DIY private Jupyter cloud

# %% [markdown]
# # [robots-from-jupyter.github.io](https://robots-from-jupyter.github.io)
