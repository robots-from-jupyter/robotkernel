# %% [markdown]
# # Example: The latest XKCD in Robot

# %% [markdown]
# Also this notebook is associated with Robot Framework kernel, and may therefore contain Robot Framework suite with tests or tasks. In this notebook we **fetch and display the latest XKCD strip** using just Robot Framework keywords.

# %% [markdown]
# As a prerequisite, we have been given the XKCD HTTP API URL `https://xkcd.com/info.0.json` for fetching information of the latest strip in JSON.
#
# Let's save that URL into a variable.

# %%
*** Variables ***

${url}  https://xkcd.com/info.0.json

# %% [markdown]
# Then we continue with [RESTinstance](https://asyrjasalo.github.io/RESTinstance/) keyword library for easily fetching JSON information from the Internet.

# %%
*** Settings ***

Library  REST

# %% [markdown]
# Now we are ready to fetch the data.

# %%
*** Tasks ***

Get XKCD JSON
    REST.Get  https://xkcd.com/info.0.json
# Out:
# <p><a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <pre>{
#     <span style="color: #008000; font-weight: bold">&quot;seconds&quot;</span>: <span style="color: #666666">0.09911400000000001</span>,
#     <span style="color: #008000; font-weight: bold">&quot;status&quot;</span>: <span style="color: #666666">200</span>,
#     <span style="color: #008000; font-weight: bold">&quot;body&quot;</span>: {
#         <span style="color: #008000; font-weight: bold">&quot;month&quot;</span>: <span style="color: #BA2121">&quot;1&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;num&quot;</span>: <span style="color: #666666">2094</span>,
#         <span style="color: #008000; font-weight: bold">&quot;link&quot;</span>: <span style="color: #BA2121">&quot;&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;year&quot;</span>: <span style="color: #BA2121">&quot;2019&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;news&quot;</span>: <span style="color: #BA2121">&quot;&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;safe_title&quot;</span>: <span style="color: #BA2121">&quot;Short Selling&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;transcript&quot;</span>: <span style="color: #BA2121">&quot;&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;alt&quot;</span>: <span style="color: #BA2121">&quot;\&quot;I&#39;m selling all my analogies at auction tomorrow, and that witch over there will give you 20 beans if you promise on pain of death to win them for her.\&quot; \&quot;What if SEVERAL people promised witches they&#39;d win, creating some kind of a ... squeeze? Gosh, you could make a lot of\u00e2\u0080\u0093\&quot; \&quot;Don&#39;t be silly! That probably never happens.\&quot;&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;img&quot;</span>: <span style="color: #BA2121">&quot;https://imgs.xkcd.com/comics/short_selling.png&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;title&quot;</span>: <span style="color: #BA2121">&quot;Short Selling&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;day&quot;</span>: <span style="color: #BA2121">&quot;4&quot;</span>
#     },
#     <span style="color: #008000; font-weight: bold">&quot;headers&quot;</span>: {
#         <span style="color: #008000; font-weight: bold">&quot;Server&quot;</span>: <span style="color: #BA2121">&quot;nginx&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Content-Type&quot;</span>: <span style="color: #BA2121">&quot;application/json&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Last-Modified&quot;</span>: <span style="color: #BA2121">&quot;Fri, 04 Jan 2019 16:05:23 GMT&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Expires&quot;</span>: <span style="color: #BA2121">&quot;Sun, 06 Jan 2019 13:26:28 GMT&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Cache-Control&quot;</span>: <span style="color: #BA2121">&quot;max-age=300&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Content-Encoding&quot;</span>: <span style="color: #BA2121">&quot;gzip&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Content-Length&quot;</span>: <span style="color: #BA2121">&quot;375&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Accept-Ranges&quot;</span>: <span style="color: #BA2121">&quot;bytes&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Date&quot;</span>: <span style="color: #BA2121">&quot;Sun, 06 Jan 2019 17:24:24 GMT&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Via&quot;</span>: <span style="color: #BA2121">&quot;1.1 varnish&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Age&quot;</span>: <span style="color: #BA2121">&quot;54&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Connection&quot;</span>: <span style="color: #BA2121">&quot;keep-alive&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;X-Served-By&quot;</span>: <span style="color: #BA2121">&quot;cache-hel6823-HEL&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;X-Cache&quot;</span>: <span style="color: #BA2121">&quot;HIT&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;X-Cache-Hits&quot;</span>: <span style="color: #BA2121">&quot;23&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;X-Timer&quot;</span>: <span style="color: #BA2121">&quot;S1546795465.868672,VS0,VE0&quot;</span>,
#         <span style="color: #008000; font-weight: bold">&quot;Vary&quot;</span>: <span style="color: #BA2121">&quot;Accept-Encoding&quot;</span>
#     }
# }
# </pre>

# %% [markdown]
# With the **Output** keyword of RESTinstance library, we can select the URL from the **response**.

# %%
*** Tasks ***

Get url from the response
    Output  response body img
# Out:
# <p><a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>

# %% [markdown]
# Woah! What just happened? Our keyword call `Output  response body img` returned string containing the URL of the latest XKCD strip image. For convenience, the underlying Robot Framework IPython kernel feed that URL into IPython display Image helper class, which fetched the image and returned in a form that JupyterLab could display directly.

# %% [markdown]
# Because this was too easy. Let's do this one more time with screen scraping the strip directly from https://xkcd.com/. For this we use [SeleniumLibrary](http://robotframework.org/SeleniumLibrary/SeleniumLibrary.html) for browser automation and [SeleniumScreenshots](https://datakurre.github.io/robotframework-seleniumscreenshots/) for cropping the strip from the page.

# %%
*** Settings ***

Library  SeleniumLibrary
Library  SeleniumScreenshots

# %% [markdown]
# With SeleniumLibrary we need to first open a browser to interact with.

# %%
*** Tasks ***

Open browser at xkcd.com
    Open browser  https://xkcd.com/  browser=firefox
# Out:
# <p><a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>
# <span style="color: #666666">1</span>

# %% [markdown]
# (The number we see as the result of the executed cell is the index of the opened browser, as documented for the **Open browser** keyword.)

# %% [markdown]
# Now we can use **Capture and crop page screenshot** keyword from SeleniumScreenshots to finish the task.

# %%
*** Tasks ***

Screenshot the latest XKCD strip
    Capture and crop page screenshot
    ...  xkcd.png  id:comic
# Out:
# <p><a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>

# %% [markdown]
# All is good, except that we have now an open SeleniumLibrary-controlled test browser open and running.
#
# The test browser can be closed simply by closing down the notebook, but that works only as long as this Robot Framework task suite is only run with Jupyter.
#
# To make the suite properly close the test browser also when being run outside Jupyter, we should configure a test suite teardown setting for that.

# %%
*** Settings ***

Suite teardown  Close all browsers

# %%
*** Tasks ***

Close all browsers
    No operation  # let the teardown close the browser
# Out:
# <p><a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='log.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Log</a> | <a href="javascript:(function(el){var w=window.open();var d='...';w.document.open();w.document.write(window.atob(d));w.document.close();var a=w.document.createElement('a');a.appendChild(w.document.createTextNode('Download'));a.href='data:text/html;base64,' + d;a.download='report.html';a.style='position:fixed;top:0;right:0;color:white;background:black;text-decoration:none;font-weight:bold;padding:7px 14px;border-radius:0 0 0 5px;';w.document.body.append(a);})(this);">Report</a></p>

# %% [markdown]
# The XKCD strip from https://xkcd.com/ is licensed under a Creative Commons Attribution-NonCommercial 2.5 License.
