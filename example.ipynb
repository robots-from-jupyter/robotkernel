# %%
*** Settings ***

Library  Selenium2Library
Library  Selenium2Screenshots

Suite teardown  Close all browsers

# %%
*** Keywords ***

Open url
    [Arguments]  ${url}
    Open browser  ${url}  browser=headlessfirefox
    Set window size  800  600

# %%
*** Test Cases ***

Show the new Robot Framework logo
    Open url  https://twitter.com/robotframework
    Page should contain  Robot Framework
    Capture and crop page screenshot  robotframework.png
    ...  css=.ProfileAvatar-image
# Out:
# <a href="javascript:(function(){var w=window.open();w.document.open();w.document.write(window.atob('...'));w.document.close();})();" ">Log</a> | <a href="javascript:(function(){var w=window.open();w.document.open();w.document.write(window.atob('...'));w.document.close();})();" ">Report</a>
